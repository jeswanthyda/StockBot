# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib
import matplotlib.pyplot as plt
import os
# Make plots bigger
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
import time

from bs4 import BeautifulSoup 
import requests
import pandas as pd

# %%
#some examples - get Facebook, Apple stock value 
def parsePrice():
    r = requests.get('https://finance.yahoo.com/quote/FB?p=FB')
    soup = BeautifulSoup(r.text,"lxml")
    price = soup.find_all('div', {'class':'My(6px) Pos(r) smartphone_Mt(6px)'})[0].find('span').text
    
#     r= requests.get('https://finance.yahoo.com/quote/AAPL?p=AAPL')
#     soup = BeautifulSoup(r.text, "lxml")
#     price = soup.find_all('div', {'class' : "My(6px) Pos(r) smartphone_Mt(6px)"})[0].find('span').text

    return price

# while True:
#     print(parsePrice())

print(parsePrice())
# Out:
# 210.88

# %%
#getting companies filtered in order of most percentage change
names = []
#symbols store unique company identifier
symbols = []
prices = []
changes = []
percentChanges = []
r = requests.get('https://finance.yahoo.com/gainers')
soup = BeautifulSoup(r.text, "lxml")
soup.prettify('utf-8')
for row in soup.find_all('tr', attrs={'class': 'simpTblRow'}):
    for symbol in row.find_all('td', attrs={'aria-label':'Symbol'}):
        symbols.append(symbol.text)
    for name in row.find_all('td', attrs={'aria-label':'Name'}):
        names.append(name.text)
    for price in row.find_all('td', attrs={'aria-label':'Price (Intraday)'}):
        #prices.append(price.find('span').text)
        prices.append(price.text)
    for change in row.find_all('td', attrs={'aria-label':'Change'}):
        #changes.append(change.find('span').text)
        changes.append(change.text)
    for percentChange in row.find_all('td', attrs={'aria-label':'% Change'}):
        percentChanges.append(percentChange.text)

# %%
print(symbols)
print(names)
# print(prices)
# print(changes)
# print(percentChanges)
# Out:
# ['NEXOF', 'NEXOY', 'WHGRF', 'DKNG', 'CGC', 'SCEXF', 'NVAX', 'SSRM', 'ALIAF', 'FANDF', 'TSSLF', 'CURLF', 'ADPT', 'PAAS', 'FBASF', 'EDNMY', 'SRPT', 'ONEM', 'SBSW', 'RARE', 'SFIX', 'GLOB', 'BC', 'GEAGY', 'AMSYF', 'NEWR', 'KRTX', 'OCFT', 'CRSP', 'PENN', 'ZLAB', 'JBT', 'TPTX', 'VAC', 'LCII', 'LZRFY', 'ROYMY', 'EQUEY', 'BCPC', 'GGNPF', 'PTON', 'ACAD', 'FSLY', 'MLSPF', 'PHJMF', 'PAGS', 'INSM', 'PRLB', 'CAHPF', 'BHF', 'GEBHY', 'BWXT', 'PINS', 'APPN', 'FATE', 'EQM', 'BHVN', 'DCPH', 'ALLO', 'RCL', 'EDRVF', 'AU', 'RGEN', 'WIX', 'QDEL', 'IMPUY', 'TYL', 'THO', 'PTCT', 'TWOU', 'EDVMF', 'VLEEY', 'CIEN', 'CVE', 'GPS', 'CLDR', 'TRGP', 'PUBGY', 'BAK', 'NVTA', 'LRENY', 'GRBMF', 'FIZZ', 'FNMA', 'NVDA', 'SIGI', 'ARGX', 'CHE', 'MDLA', 'SDGR', 'CARG', 'AVLR', 'GH', 'OKE', 'APPF', 'MCK', 'TJX', 'SGBAF', 'FMCC', 'RNG']
# ['NEXON Co., Ltd.', 'NEXON Co., Ltd.', 'WH Group Limited', 'DraftKings Inc.', 'Canopy Growth Corporation', 'Saracen Mineral Holdings Limited', 'Novavax, Inc.', 'SSR Mining Inc.', 'Alacer Gold Corp.', 'FirstRand Limited', 'Telesites, S.A.B. de C.V.', 'Curaleaf Holdings, Inc.', 'Adaptive Biotechnologies Corporation', 'Pan American Silver Corp.', 'Fibra UNO', 'Edenred SA', 'Sarepta Therapeutics, Inc.', '1Life Healthcare, Inc.', 'Sibanye Stillwater Limited', 'Ultragenyx Pharmaceutical Inc.', 'Stitch Fix, Inc.', 'Globant S.A.', 'Brunswick Corporation', 'GEA Group Aktiengesellschaft', 'ArcelorMittal', 'New Relic, Inc.', 'Karuna Therapeutics, Inc.', 'OneConnect Financial Technology Co., Ltd.', 'CRISPR Therapeutics AG', 'Penn National Gaming, Inc.', 'Zai Lab Limited', 'John Bean Technologies Corporation', 'Turning Point Therapeutics, Inc.', 'Marriott Vacations Worldwide Corporation', 'LCI Industries', 'Localiza Rent a Car S.A.', 'Royal Mail plc', 'Equatorial Energia S.A.', 'Balchem Corporation', 'PT Gudang Garam Tbk', 'Peloton Interactive, Inc.', 'ACADIA Pharmaceuticals Inc.', 'Fastly, Inc.', 'Melrose Industries PLC', 'PT Hanjaya Mandala Sampoerna Tbk', 'PagSeguro Digital Ltd.', 'Insmed Incorporated', 'Proto Labs, Inc.', 'Evolution Mining Limited', 'Brighthouse Financial, Inc.', 'Genting Berhad', 'BWX Technologies, Inc.', 'Pinterest, Inc.', 'Appian Corporation', 'Fate Therapeutics, Inc.', 'EQM Midstream Partners, LP', 'Biohaven Pharmaceutical Holding Company Ltd.', 'Deciphera Pharmaceuticals, Inc.', 'Allogene Therapeutics, Inc.', 'Royal Caribbean Cruises Ltd.', 'EDP Renovaveis, S.A.', 'AngloGold Ashanti Limited', 'Repligen Corporation', 'Wix.com Ltd.', 'Quidel Corporation', 'Impala Platinum Holdings Limited', 'Tyler Technologies, Inc.', 'Thor Industries, Inc.', 'PTC Therapeutics, Inc.', '2U, Inc.', 'Endeavour Mining Corporation', 'Valeo SA', 'Ciena Corporation', 'Cenovus Energy Inc.', 'The Gap, Inc.', 'Cloudera, Inc.', 'Targa Resources Corp.', 'Publicis Groupe S.A.', 'Braskem S.A.', 'Invitae Corporation', 'Lojas Renner S.A.', 'Grupo Bimbo, S.A.B. de C.V.', 'National Beverage Corp.', 'Federal National Mortgage Association', 'NVIDIA Corporation', 'Selective Insurance Group, Inc.', 'argenx SE', 'Chemed Corporation', 'Medallia, Inc.', 'Schrodinger, Inc.', 'CarGurus, Inc.', 'Avalara, Inc.', 'Guardant Health, Inc.', 'ONEOK, Inc.', 'AppFolio, Inc.', 'McKesson Corporation', 'The TJX Companies, Inc.', 'SES S.A.', 'Freddie Mac', 'RingCentral, Inc.']

# %% [markdown]
# ![Screenshot%202020-05-18%20at%201.36.09%20AM.png](attachment:Screenshot%202020-05-18%20at%201.36.09%20AM.png)

# %%
#get DraftKingsInc data from Alpha Vantage
API_KEY = 'NL3CWQEZMABADZPX'
ts = TimeSeries(key=API_KEY, output_format='pandas')
data, meta_data = ts.get_intraday(symbol= symbols[3],interval='1min', outputsize='full')
data.describe()

#outputsize can be compact - returns last 100 points
# Out:
#            1. open      2. high       3. low     4. close      5. volume
# count  1936.000000  1936.000000  1936.000000  1936.000000    1936.000000
# mean     26.401244    26.470592    26.333841    26.401881   32781.446281
# std       1.394754     1.405172     1.385869     1.396821   43811.756221
# min      23.520000    23.660000    23.500000    23.510300     177.000000
# 25%      25.484200    25.587500    25.395550    25.483750   10985.000000
# 50%      26.260000    26.340000    26.200050    26.260000   19859.500000
# 75%      27.312500    27.400000    27.240000    27.315425   38263.750000
# max      29.357600    29.400000    29.280000    29.355600  766275.000000

# %%
print(meta_data)
data['4. close'].plot()
plt.title('Intraday Times Series for the stock (1 min)')
plt.grid()
plt.show()
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume', '2. Symbol': 'DKNG', '3. Last Refreshed': '2020-05-15 16:00:00', '4. Interval': '1min', '5. Output Size': 'Full size', '6. Time Zone': 'US/Eastern'}

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas')
while True:
    data,meta_data = ts.get_intraday(symbol=symbols[3], interval='1min', outputsize='compact')
    print(data)
    #data.to_excel("output.xlsx")
    time.sleep(60)
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-05-15 16:00:00  29.2300    29.32   29.17   29.1900   171097.0
# 2020-05-15 15:59:00  29.1700    29.23   29.17   29.2300   125919.0
# 2020-05-15 15:58:00  29.2000    29.20   29.15   29.1850    90210.0
# 2020-05-15 15:57:00  29.1852    29.20   29.15   29.1800    81685.0
# 2020-05-15 15:56:00  29.1900    29.20   29.15   29.1800    42415.0
# ...                      ...      ...     ...       ...        ...
# 2020-05-15 14:25:00  28.3700    28.40   28.30   28.3175    23437.0
# 2020-05-15 14:24:00  28.3783    28.40   28.31   28.4000    23631.0
# 2020-05-15 14:23:00  28.4700    28.50   28.29   28.3200    72380.0
# 2020-05-15 14:22:00  28.4400    28.49   28.43   28.4837    16121.0
# 2020-05-15 14:21:00  28.4400    28.46   28.38   28.4600    21646.0
#
# [100 rows x 5 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-2388fdaf4eef> in <module>
#       4     print(data)
#       5     #data.to_excel("output.xlsx")
# ----> 6     time.sleep(60)
#
# KeyboardInterrupt:

# %%
data = data.drop('5. volume',1)
data.plot()
plt.title('Intraday Times Series for the stock (1 min)')
plt.grid()
plt.show()

# %%
#experiment - fetch stock values for top 5 companies every minute and dump to dictionary 
from collections import defaultdict
stocks = defaultdict()

ts = TimeSeries(key=API_KEY, output_format='pandas')
while True:
    for i in range(5):
        data, meta_data = ts.get_intraday(symbol= symbols[i], interval='1min', outputsize='compact')
        print(data)
        if symbols[i] not in stocks:
            stocks[symbols[i]]=[]
        stocks[symbols[i]].append(data)
        print(symbols[i])
    time.sleep(60)
# 2020-05-14 14:47:00    0.840    0.840  0.8400    0.8400     2518.0
# 2020-05-12 15:11:00    0.880    0.880  0.8800    0.8800     7556.0
# 2020-05-11 15:23:00    0.910    0.910  0.9100    0.9100     3080.0
# 2020-05-11 14:50:00    0.915    0.915  0.9150    0.9150     5376.0
# 2020-05-11 11:36:00    0.870    0.870  0.8601    0.8601      510.0
# 2020-05-11 09:47:00    1.200    1.200  1.2000    1.2000        0.0
# WHGRF
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-124-182ab8db1536> in <module>
#       5 while True:
#       6     for i in range(10):
# ----> 7         data, meta_data = ts.get_intraday(symbol= symbols[i], interval='1min', outputsize='compact')
#       8         print(data)
#       9         if symbols[i] not in stocks:
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/site-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/site-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#     162
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/site-packages/alpha_vantage/alphavantage.py in _handle_api_call(self, url)
#     330         if 'json' in self.output_format.lower() or 'pandas' in \
#     331                 self.output_format.lower():
# --> 332             json_response = response.json()
#     333             if not json_response:
#     334                 raise ValueError(
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/opt/anaconda3/envs/summer/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
print(stocks)
# Out:
# defaultdict(None, {'NEXOF': [                     1. open  2. high  3. low  4. close  5. volume
# date
# 2020-05-15 15:50:00    21.03    21.03   21.03     21.03    17000.0
# 2020-05-15 15:13:00    20.00    20.00   20.00     20.00      595.0
# 2020-05-15 12:50:00    21.03    21.03   21.03     21.03     3799.0
# 2020-05-13 11:46:00    16.50    16.50   16.50     16.50     5389.0], 'NEXOY': [                     1. open  2. high  3. low  4. close  5. volume
# date
# 2020-05-15 15:58:00   20.790    20.79  20.790     20.79     5950.0

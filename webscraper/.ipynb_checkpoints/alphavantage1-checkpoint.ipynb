# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib
import matplotlib.pyplot as plt
import os
# Make plots bigger
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
import time

# %%
API_KEY = 'NL3CWQEZMABADZPX'
ts = TimeSeries(key=API_KEY, output_format='pandas')
data, meta_data = ts.get_intraday(symbol='IBM',interval='1min', outputsize='full')
data.describe()

#outputsize can be 'compact' - returns last 100 points
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  1935.000000  1935.000000  1935.000000  1935.000000  1.935000e+03
# mean    118.704074   118.763604   118.645716   118.702640  1.271900e+04
# std       3.475594     3.463815     3.484146     3.473481  5.413610e+04
# min     111.920000   112.090000   111.810000   111.910000  0.000000e+00
# 25%     115.880000   115.950000   115.830000   115.890000  3.788500e+03
# 50%     116.960000   117.030000   116.905100   116.965000  5.954000e+03
# 75%     122.760000   122.800000   122.709250   122.743500  9.854000e+03
# max     124.270000   124.320000   124.250000   124.260000  1.414834e+06

# %%
data['4. close'].plot()
plt.title('Intraday Times Series for the stock (1 min)')
plt.grid()
plt.show()

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2020-05-15 16:00:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
#output_format can be 'csv' or 'pandas'
ts = TimeSeries(key=API_KEY, output_format='csv')
data_csv,_ = ts.get_intraday(symbol='IBM',interval='1min', outputsize='compact')
data_csv

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas')
while True:
    data,meta_data = ts.get_intraday(symbol='IBM',interval='1min', outputsize='full')
    print(data)
    #data.to_excel("output.xlsx")
    time.sleep(60)
# Out:
#                      1. open   2. high   3. low  4. close  5. volume
# date
# 2020-05-15 16:00:00  116.920  117.0600  116.870  117.0100    44396.0
# 2020-05-15 15:59:00  116.820  116.9500  116.810  116.9300    30418.0
# 2020-05-15 15:58:00  116.890  116.9100  116.810  116.8100    16442.0
# 2020-05-15 15:57:00  116.800  116.9000  116.785  116.9000    14698.0
# 2020-05-15 15:56:00  116.760  116.8100  116.740  116.8000    13321.0
# ...                      ...       ...      ...       ...        ...
# 2020-05-11 09:35:00  121.360  121.4100  121.200  121.2200    14164.0
# 2020-05-11 09:34:00  121.310  121.4975  121.300  121.3500    11981.0
# 2020-05-11 09:33:00  121.380  121.5800  121.260  121.2900     9177.0
# 2020-05-11 09:32:00  121.705  121.7300  121.330  121.3300    19569.0
# 2020-05-11 09:31:00  121.810  121.9600  121.550  121.6601   100005.0
#
# [1935 rows x 5 columns]
#                      1. open   2. high   3. low  4. close  5. volume
# date
# ...

# %% [markdown]
# error encountered: no module named openpyxl
# conda install openpyxl

# %%
data = data.drop('5. volume',1)
data.plot()
plt.title('Intraday Times Series for the stock (1 min)')
plt.grid()
plt.show()

# %%
ts.output_format='pandas'
data, meta_data = ts.get_batch_stock_quotes(symbols=('MSFT', 'FB', 'IBM'))
data.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-eb71cd39652d> in <module>
#       1 ts.output_format='pandas'
# ----> 2 data, meta_data = ts.get_batch_stock_quotes(symbols=('MSFT', 'FB', 'IBM'))
#       3 data.describe()
#
# AttributeError: 'TimeSeries' object has no attribute 'get_batch_stock_quotes'
